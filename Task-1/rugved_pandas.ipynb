# %%
import pandas as pd

# %%
s=pd.Series([300,400,250],index=['tv','ac','fridge'])
s
# Out:
# tv        300
# ac        400
# fridge    250
# dtype: int64

# %%
matches=pd.read_csv("matches.csv")

# %%
matches.shape
# Out:
# (756, 17)

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches=pd.read_csv("matches.csv",index_col=0)
matches.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
matches['season']
# Out:
# id
# 1        2017
# 2        2017
# 3        2017
# 4        2017
# 5        2017
#          ...
# 11347    2019
# 11412    2019
# 11413    2019
# 11414    2019
# 11415    2019
# Name: season, Length: 756, dtype: int64

# %%
matches['city'][3]
# Out:
# 'Rajkot'

# %%
matches.iloc[0:7:2,0:10]
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 7     2017     Mumbai  2017-04-09        Kolkata Knight Riders
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
# 7                Mumbai Indians               Mumbai Indians         field
#
#     result  dl_applied                       winner
# id
# 1   normal           0          Sunrisers Hyderabad
# 3   normal           0        Kolkata Knight Riders
# 5   normal           0  Royal Challengers Bangalore
# ...

# %%
matches[-2:]
# Out:
#        season           city      date           team1                team2  \
# id
# 11414    2019  Visakhapatnam  10/05/19  Delhi Capitals  Chennai Super Kings
# 11415    2019      Hyderabad  12/05/19  Mumbai Indians  Chennai Super Kings
#
#                toss_winner toss_decision  result  dl_applied  \
# id
# 11414  Chennai Super Kings         field  normal           0
# 11415       Mumbai Indians           bat  normal           0
#
#                     winner  win_by_runs  win_by_wickets player_of_match  \
# id
# 11414  Chennai Super Kings            0               6    F du Plessis
# 11415       Mumbai Indians            1               0       JJ Bumrah
#
#                                     venue        umpire1         umpire2  \
# id
# 11414                    ACA-VDCA Stadium  Sundaram Ravi  Bruce Oxenford
# 11415  Rajiv Gandhi Intl. Cricket Stadium    Nitin Menon       Ian Gould
#
#                        umpire3
# id
# 11414  Chettithody Shamshuddin
# ...

# %%
matches.loc[1,'city']
# Out:
# 'Hyderabad'

# %%
matches.loc[1:6,['city','date','team1','season']]
# Out:
#          city        date                        team1  season
# id
# 1   Hyderabad  2017-04-05          Sunrisers Hyderabad    2017
# 2        Pune  2017-04-06               Mumbai Indians    2017
# 3      Rajkot  2017-04-07                Gujarat Lions    2017
# 4      Indore  2017-04-08       Rising Pune Supergiant    2017
# 5   Bangalore  2017-04-08  Royal Challengers Bangalore    2017
# 6   Hyderabad  2017-04-09                Gujarat Lions    2017

# %%
matches.loc[1:6,['city','season']]
# Out:
#          city  season
# id
# 1   Hyderabad    2017
# 2        Pune    2017
# 3      Rajkot    2017
# 4      Indore    2017
# 5   Bangalore    2017
# 6   Hyderabad    2017

# %%
import pandas as pd

matches = pd.read_csv("matches.csv")
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches=pd.read_csv("matches.csv",index_col=0)

# %%
matches['city']
# Out:
# id
# 1            Hyderabad
# 2                 Pune
# 3               Rajkot
# 4               Indore
# 5            Bangalore
#              ...
# 11347           Mumbai
# 11412          Chennai
# 11413    Visakhapatnam
# 11414    Visakhapatnam
# 11415        Hyderabad
# Name: city, Length: 756, dtype: object

# %%
matches.iloc[0:9,5:10]
# Out:
#                     toss_winner toss_decision  result  dl_applied  \
# id
# 1   Royal Challengers Bangalore         field  normal           0
# 2        Rising Pune Supergiant         field  normal           0
# 3         Kolkata Knight Riders         field  normal           0
# 4               Kings XI Punjab         field  normal           0
# 5   Royal Challengers Bangalore           bat  normal           0
# 6           Sunrisers Hyderabad         field  normal           0
# 7                Mumbai Indians         field  normal           0
# 8   Royal Challengers Bangalore           bat  normal           0
# 9        Rising Pune Supergiant         field  normal           0
#
#                          winner
# id
# 1           Sunrisers Hyderabad
# 2        Rising Pune Supergiant
# 3         Kolkata Knight Riders
# 4               Kings XI Punjab
# 5   Royal Challengers Bangalore
# 6           Sunrisers Hyderabad
# 7                Mumbai Indians
# ...

# %%
matches.set_index("season")
# Out:
#                  city        date                        team1  \
# season
# 2017        Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2017             Pune  2017-04-06               Mumbai Indians
# 2017           Rajkot  2017-04-07                Gujarat Lions
# 2017           Indore  2017-04-08       Rising Pune Supergiant
# 2017        Bangalore  2017-04-08  Royal Challengers Bangalore
# ...               ...         ...                          ...
# 2019           Mumbai    05/05/19        Kolkata Knight Riders
# 2019          Chennai    07/05/19          Chennai Super Kings
# 2019    Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 2019    Visakhapatnam    10/05/19               Delhi Capitals
# 2019        Hyderabad    12/05/19               Mumbai Indians
#
#                               team2                  toss_winner  \
# season
# 2017    Royal Challengers Bangalore  Royal Challengers Bangalore
# ...

# %%
matches.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
matches.loc[(matches['toss_winner'] == 'Royal Challengers Bangalore') & (matches['toss_decision']=='bat')]
# Out:
#       id  season            city        date                        team1  \
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 7      8    2017          Indore  2017-04-10  Royal Challengers Bangalore
# 36    37    2017          Mumbai  2017-05-01  Royal Challengers Bangalore
# 54    55    2017           Delhi  2017-05-14  Royal Challengers Bangalore
# 93    94    2008      Chandigarh  2008-05-12  Royal Challengers Bangalore
# 106  107    2008         Chennai  2008-05-21  Royal Challengers Bangalore
# 118  119    2009       Cape Town  2009-04-18  Royal Challengers Bangalore
# 126  127    2009          Durban  2009-04-24  Royal Challengers Bangalore
# 128  129    2009  Port Elizabeth  2009-04-26  Royal Challengers Bangalore
# 138  139    2009          Durban  2009-05-01  Royal Challengers Bangalore
# 170  171    2009       Centurion  2009-05-21  Royal Challengers Bangalore
# 201  202    2010         Chennai  2010-03-31  Royal Challengers Bangalore
# ...

# %%
matches[(matches['city']=='Bangalore') & ((matches['team1']=='Royal Challengers Bangalore')|(matches['team2']=='Royal Challengers Bangalore'))]
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 16    17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 29    30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# 41    42    2017  Bangalore  2017-05-05              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 616  617    2016  Bangalore  2016-05-11  Royal Challengers Bangalore
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 625  626    2016  Bangalore  2016-05-18  Royal Challengers Bangalore
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
matches.team1 == 'Mumbai Indians'
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 751    False
# 752    False
# 753    False
# 754    False
# 755     True
# Name: team1, Length: 756, dtype: bool

# %%
matches.loc[(matches.team1=='Mumbai Indians') & (matches.team2=='Royal Challengers Bangalore')]
# Out:
#         id  season    city        date           team1  \
# 62      63    2008  indore  2008-04-20  Mumbai Indians
# 142    143    2009  indore  2009-05-03  Mumbai Indians
# 152    153    2009  indore  2009-05-10  Mumbai Indians
# 187    188    2010  indore  2010-03-20  Mumbai Indians
# 225    226    2010  indore  2010-04-17  Mumbai Indians
# 230    231    2010  indore  2010-04-21  Mumbai Indians
# 359    360    2012  indore  2012-05-09  Mumbai Indians
# 416    417    2013  indore  2013-04-27  Mumbai Indians
# 461    462    2014  indore  2014-04-19  Mumbai Indians
# 483    484    2014  indore  2014-05-06  Mumbai Indians
# 533    534    2015  indore  2015-04-19  Mumbai Indians
# 649   7907    2018  indore    17/04/18  Mumbai Indians
# 702  11143    2019  indore    28/03/19  Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 62   Royal Challengers Bangalore               Mumbai Indians           bat
# ...

# %%
matches.loc[matches.city.isin(['Hyderabad','Indore'])]
# Out:
#         id  season       city        date                        team1  \
# 0        1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 3        4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5        6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7        8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 18      19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# ..     ...     ...        ...         ...                          ...
# 725  11321    2019  Hyderabad    14/04/19               Delhi Capitals
# 728  11324    2019  Hyderabad    17/04/19          Chennai Super Kings
# 733  11329    2019  Hyderabad    21/04/19        Kolkata Knight Riders
# 743  11339    2019  Hyderabad    29/04/19          Sunrisers Hyderabad
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...
