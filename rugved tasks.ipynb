# %%
import pandas as pd

# %%
matches=pd.read_csv('matches.csv')

# %%
matches.head()

# %%
matches.tail()

# %%
matches.insert(3,'ball used','white')

# %%
matches

# %%
matches.loc[2,'city']
# Out:
# 'Rajkot'

# %%
matches.loc[2:5,'city']

# %%
matches.iloc[2:5,1]

# %%
matches.head(100)

# %%
matches.city.unique

# %%
matches[matches['city']=='mumbai'].value_counts()

# %%
matches.isnull().sum().sum()

# %%
matches[matches['city']=='mumbai'].value_counts().value_counts()

# %%
matches['venue'].max()

# %%
matches[matches['season']== 2008].count()

# %%
matches[matches['season']==2008].shape[0]

# %%
matches['city'].max()

# %%
city_counts = matches['city'].value_counts()
city_counts
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
city_counts.idxmin()

# %%
matches[matches['toss_decision']=='field']

# %%
matches[(matches['toss_winner'] == 'Royal Challengers Bangalore') &
        (matches['toss_decision'] == 'bat')].shape[0]

# %%
matches.groupby(['toss_winner', 'toss_decision']).size()

# %%
matches.win_by_runs.describe()

# %%
matches[matches['result']=='tie']
# Out:
#         id  season       city        date                        team1  \
# 33      34    2017     Rajkot  2017-04-29                Gujarat Lions
# 125    126    2009  Cape Town  2009-04-23             Rajasthan Royals
# 189    190    2010    Chennai  2010-03-21              Kings XI Punjab
# 387    388    2013  Hyderabad  2013-04-07  Royal Challengers Bangalore
# 400    401    2013  Bangalore  2013-04-16             Delhi Daredevils
# 475    476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 535    536    2015  Ahmedabad  2015-04-21             Rajasthan Royals
# 705  11146    2019      Delhi    30/03/19        Kolkata Knight Riders
# 746  11342    2019     Mumbai    02/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 33                Mumbai Indians                Gujarat Lions           bat
# 125        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
m=matches['player_of_match'].value_counts()
n=m>3

# %%
n.value_counts()

# %%
u1=matches.umpire1.value_counts()
u2=matches.umpire2.value_counts()
u3=matches.umpire3.value_counts()
u1

# %%
(u1+u2+u3).idxmax()

# %%
matches['season'].value_counts()

# %%
matches

# %%
deliveries=pd.read_csv('deliveries.csv')
deliveries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df_grouped = deliveries.groupby('match_id').sum()
df_grouped
# Out:
#           inning                                       batting_team  \
# match_id
# 1            371  Sunrisers HyderabadSunrisers HyderabadSunriser...
# 2            369  Mumbai IndiansMumbai IndiansMumbai IndiansMumb...
# 3            314  Gujarat LionsGujarat LionsGujarat LionsGujarat...
# 4            369  Rising Pune SupergiantRising Pune SupergiantRi...
# 5            372  Royal Challengers BangaloreRoyal Challengers B...
# ...          ...                                                ...
# 11347        328  Kolkata Knight RidersKolkata Knight RidersKolk...
# 11412        350  Chennai Super KingsChennai Super KingsChennai ...
# 11413        376  Sunrisers HyderabadSunrisers HyderabadSunriser...
# 11414        355  Delhi CapitalsDelhi CapitalsDelhi CapitalsDelh...
# 11415        372  Mumbai IndiansMumbai IndiansMumbai IndiansMumb...
#
#                                                bowling_team  over  ball  \
# match_id
# ...

# %%
df_grouped.index.rename('id', inplace=True)

# %%
df_grouped2=pd.merge(matches,df_grouped,on='id')

# %%
df_grouped2
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df_grouped2.groupby('season')['total_runs'].sum()
# Out:
# season
# 2008    17937
# 2009    16353
# 2010    18883
# 2011    21154
# 2012    22453
# 2013    22602
# 2014    18931
# 2015    18353
# 2016    18862
# 2017    18786
# 2018    20706
# 2019    20270
# Name: total_runs, dtype: int64

# %%
top_batsman=deliveries.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)
top_batsman
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
wicket=deliveries.groupby('bowler')['player_dismissed']
wicket
